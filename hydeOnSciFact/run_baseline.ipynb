# %% [markdown]
# # SciFact Baseline Dense Retrieval
#
# This notebook runs retrieval-only baseline on SciFact.

# %%
# %cd ./
# !python main.py --mode baseline --split test --prefer_beir --top_ks 1,3,5,10 --output_dir results/baseline
